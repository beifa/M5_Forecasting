# %% [markdown]
# <a href="https://colab.research.google.com/github/beifa/M5_Forecasting/blob/master/ver.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Description:
#
# 0.47379 v35 changed 'mean_encoding_df.pkl' with mean_features   to .iloc[:, 2:]
# take all.
#
# 0.49035 v36 change period - 3*365= 1095
#
# 0.47326 v37 add new data, droped in lags first row
#
# 0.47114 v38 add 28 lags
#
# 0.47438 v39 make train current store(CA_1,2,3,4).....
#
# 0.47209 v40 drop encode train on group
#     encode_f = [
#
#     'enc_dept_id_mean',
#     'enc_item_id_mean',
#     'enc_item_id_std',
#     'enc_item_id_state_id_mean',
#     'enc_item_id_state_id_std',
#     'enc_item_id_store_id_mean',
#     'enc_item_id_store_id_std'
#
#         ]
#
# 0.47679 v41 group, drop 'enc_dept_id_mean' под сомнением
#
# 0.47513 v42 group, add 'enc_state_id_mean','enc_store_id_std','enc_state_id_cat_id_mean',
#
# 0.47269 v43 add 'enc_state_id_std', 'enc_cat_id_mean', 'enc_state_id_dept_id_std',
#
# 0.49848 v44 add 'enc_store_id_cat_id_mean','enc_store_id_dept_id_std','enc_dept_id_std',
#
# 0.47432 v45 drop 'event_type1'
#
# 0.47173 v46 drop f in encode
#     'enc_dept_id_mean',
#     'enc_item_id_mean',
#     'enc_item_id_std',
#     #'enc_item_id_state_id_mean',
#     'enc_item_id_state_id_std',
#     'enc_item_id_store_id_mean',
#     #'enc_item_id_store_id_std'
#
# 0.47097 v47 drop f in encode
#     'enc_dept_id_mean',
#     #'enc_item_id_mean',
#     'enc_item_id_std',
#     'enc_item_id_state_id_mean',
#     #'enc_item_id_state_id_std',
#     'enc_item_id_store_id_mean',
#     'enc_item_id_store_id_std'
#
# 0.47301 v48 drop f in encode
#     'enc_dept_id_mean',
#     #'enc_item_id_mean',
#     'enc_item_id_std',
#     'enc_item_id_state_id_mean',
#     'enc_item_id_state_id_std',
#     #'enc_item_id_store_id_mean',
#     #'enc_item_id_store_id_std'
#
# **0.47034 v49** drop f in encode
#     'enc_dept_id_mean',
#     'enc_item_id_mean',
#     #'enc_item_id_std',
#     'enc_item_id_state_id_mean',
#     #'enc_item_id_state_id_std',
#     'enc_item_id_store_id_mean',
#     #'enc_item_id_store_id_std'
#
# 0.47581 v50
#     'enc_dept_id_mean',
#     'enc_item_id_mean',
#     #'enc_item_id_std',
#     'enc_item_id_state_id_mean',
#     #'enc_item_id_state_id_std',
#     #'enc_item_id_store_id_mean',
#     #'enc_item_id_store_id_std'
#
# 0.47419 v51
#     'enc_dept_id_mean',
#     'enc_item_id_mean',
#     #'enc_item_id_std',
#     #'enc_item_id_state_id_mean',
#     #'enc_item_id_state_id_std',
#     'enc_item_id_store_id_mean',
#     #'enc_item_id_store_id_std'
#
# 0.47392 v52
#     'enc_dept_id_mean',
#     'enc_item_id_mean',
#     #'enc_item_id_std',
#     #'enc_item_id_state_id_mean',
#     #'enc_item_id_state_id_std',
#     #'enc_item_id_store_id_mean',
#     #'enc_item_id_store_id_std'
#
# 0.47219 v53
#     'enc_cat_id_mean',
#     'enc_dept_id_mean',
#     'enc_item_id_mean',
#     #'enc_item_id_std',
#     'enc_item_id_state_id_mean',
#     #'enc_item_id_state_id_std',
#     'enc_item_id_store_id_mean',
#     #'enc_item_id_store_id_std'
#
# 0.47119 v54 all drop
#     'rolling_mean_7',
#     'rolling_std_7',
#     'rolling_mean_14',
#     'rolling_std_14',
#     'rolling_mean_30',
#     'rolling_std_30',
#     'rolling_mean_60',
#     'rolling_std_60',
#     'rolling_mean_180',
#     'rolling_std_180',
#
# 0.47444 v55
#     'rolling_mean_7',
#     'rolling_std_7',
#     'rolling_mean_14',
#     'rolling_std_14',
#     'rolling_mean_30',
#     #'rolling_std_30',
#     'rolling_mean_60',
#     'rolling_std_60',
#     #'rolling_mean_180',
#     'rolling_std_180',
#
# ----jun 6----
#
# 0.4735 - v56
#
#     #'rolling_mean_7',
#     #'rolling_std_7',
#     #'rolling_mean_14',
#     #'rolling_std_14',
#     #'rolling_mean_30',
#     'rolling_std_30',
#     #'rolling_mean_60',
#     #'rolling_std_60',
#     'rolling_mean_180',
#     #'rolling_std_180',
#
# 0.4731 - v57
#
#     #'rolling_mean_7',
#     'rolling_std_7',
#     #'rolling_mean_14',
#     #'rolling_std_14',
#     #'rolling_mean_30',
#     'rolling_std_30',
#     #'rolling_mean_60',
#     #'rolling_std_60',
#     'rolling_mean_180',
#     #'rolling_std_180',
#
# 0.4731 - v57
#
#     #'rolling_mean_7',
#     'rolling_std_7',
#     #'rolling_mean_14',
#     'rolling_std_14',
#     #'rolling_mean_30',
#     'rolling_std_30',
#     #'rolling_mean_60',
#     #'rolling_std_60',
#     'rolling_mean_180',
#     #'rolling_std_180',
#
# ---catboost----
#
# v1_1 5000 iter not more 0.5
#
# v1_2 catboost add 1000 iteratiion bad
#
# ----------------
#
# 0.47673 - v62 add new feature lags -v1
#
# 0.47340 - v63 add new feature -v2
#
# 0.47215 - v64 add new feature -v3
#
# 0.47705 - v65 lags 1+3v
#
# 0.47362 - v66 lags v2-3
#
# 0,47666 - v67
#     'ewm_lags20_v2',
#     'ewm_lags25_v2',
#
# 0,4725 - v68
#     'ewm_lags12_v2',
#     #'ewm_lags20_v2',
#     #'ewm_lags25_v2',
#     'ewm_lags32_v2'
#
# **0,4698 - v69**
#     'ewm_lags12_v2',
#     #'ewm_lags20_v2',
#     'ewm_lags25_v2',
#     #'ewm_lags32_v2'
#
# 0.92522- v70
#      'prob_sales',
#      'mean_sales_month',
#      'sum_sales_by_day',
#      'difff_s_by_m_to_d',
#      'sales_by_y_m_std',
#      'sales_by_y_m_mean',
#      'sales_by_m_std',
#      'sales_by_m_mean',
#      'sales_by_cat_y_m_std',
#      'sales_by_cat_y_m_mean',
#      'trend_item_state',
#      'trend_item_id',
#      'd_avg_sold_state'
#
# 0.93640 - v71
#      'prob_sales',
#      'difff_s_by_m_to_d',
#      'sales_by_y_m_std',
#      'sales_by_y_m_mean',
#      'sales_by_m_std',
#      'sales_by_m_mean',
#      'trend_item_state',
#      'trend_item_id',
#      'd_avg_sold_state'
#
# 0.93744 - v72
#      'prob_sales',
#      'difff_s_by_m_to_d',
#      'sales_by_y_m_mean',
#      'sales_by_m_mean',
#      'trend_item_state',
#      'trend_item_id',
#      'd_avg_sold_state'
#
# v73
#      'prob_sales',
#      'difff_s_by_m_to_d',
#      'sales_by_y_m_std',
#      'sales_by_m_std',
#      'trend_item_id',
#      'd_avg_sold_state'
#
# 0.92341 - v74
#      'prob_sales',
#      'difff_s_by_m_to_d',
#      'trend_item_id',
#      'd_avg_sold_state'
#
# 0.49003 - v75
#      'difff_s_by_m_to_d',
#      'sales_by_cat_y_m_std',
#      'sales_by_cat_y_m_mean',
#      'trend_item_id'
#
# 0.92549 -v76
#      'prob_sales',
#      'sales_by_y_m_mean',
#      'sales_by_cat_y_m_std',
#      'sales_by_cat_y_m_mean',
#      'trend_item_state',
#      'd_avg_sold_state'
#
# 0.47981 - v77
#      'tsvd',
#      'pca',
#      'ica',
#      'grp',
#      'srp'
#
# 0.47561 -  v79
#      'wek7',
#      'wek14',
#      'wek21',
#      'wek28'
#
# 0.47593 - v80
#      'sales_by_cat_y_m_std',
#      'sales_by_cat_y_m_mean'
#
# 0.49203 - v81
#      'difff_s_by_m_to_d',
#      'trend_item_id'
#
# 0.47376 - v82
#      'sales_by_cat_y_m_std',
#      'sales_by_cat_y_m_mean',
#      'trend_item_id'
#
# 0.49180 - v83
#      'difff_s_by_m_to_d',
#      'sales_by_cat_y_m_std',
#      'sales_by_cat_y_m_mean'
#
# 0.47256 - v84
#     'trend_item_id'
#
# 0.48827 - v85
#     'difff_s_by_m_to_d'
#
# 0.47240 - v86
#     'trend_item_state'
#
# 0.47651 - v87
#      'sales_by_y_m_std',
#      'sales_by_y_m_mean'
#
# 0.47533 - v88
#      'sales_by_m_std',
#      'sales_by_m_mean'
#
# 0.47709 - v88
#      'sales_by_y_m_std',
#      'sales_by_m_std'
#
# 0.47483 - v90
#         'sales_by_cat_y_m_mean'
#
# 0.47281 - v91
#         'sales_by_cat_y_m_std'
#
# 0.93385 - v92
#         'prob_sales'
#
# 0.48515 - v93
#         'sum_sales_by_day'
#
# 0.47212 - v94
#         'mean_sales_month'
#
# 0.48774 - v95
#         'difff_s_by_m_to_d'
#
# 0,4753 - v96 'trend_item_id'
#
# **0,4690 - v97'ewm_lags12_v2'**
#
# 0,4725 - v98'ewm_lags25_v2',
#
# 0,4730 - v99 lg1lg2lg3_pca.pkl
#
# 0,4784 - v100 mem_err_splitlag4_pca_v1.pkl
#
# 0,476 - v101 mem-err-splitlag4-pca-v2
#
# 0.4755 - v102 mem_err_splitlag4_pca_v3.pkl
#
# 0.47762 - v103 mem_err_splitlag4_pca_v4.pkl
#
# 0.4727 - v104
# 'sales_by_cat_y_m_std'
# 'ewm_lags12_v2',
# 'ewm_lags25_v2',
#
# 0.4713 - v105
# 'trend_item_id'
# 'ewm_lags12_v2',
# 'ewm_lags25_v2',
#
# 0.4705 - v106
# 'mean_sales_month'
# 'ewm_lags12_v2',
# 'ewm_lags25_v2',
#
# 0.4729 - v107
# 'trend_item_id'
# 'mean_sales_month'
# 'ewm_lags12_v2',
# 'ewm_lags25_v2',
#
# 0.4736 - v108
# 'sales_by_cat_y_m_std'
# 'trend_item_id'
# 'mean_sales_month'
# 'ewm_lags12_v2',
# 'ewm_lags25_v2',
#
# 0.4735 - v109
# 'trend_item_id'
# 'ewm_lags12_v2',
#
# 0.47555 - v110
#  'ewm_lags12_v2',
#  'trend_v1',
#  'trend_v2',
#  'diff_v2_dm'
#
# **v112-----------not param--- features default 0.50474-------------**
# **v114 no param add prob features 0.90755**
#
# 0.47273 - v112(karkad)
#  'ewm_lags12_v2',
#  'trend_v1'
#
# 0.47403 - v111
#  'sales_by_cat_y_m_std',
#  'ewm_lags12_v2',
#  'trend_v1',
#  'diff_v2_dm'
#
# 0.47367 - v113
#   'ewm_lags12_v2',
#  'trend_v2'
#
# 0.47285 - v114
#  'ewm_lags12_v2',
#  'diff_v2_dm'
#
# 0.4732 - v115
# 'diff_v2_dm'
#
# 0.47323 - v116
# 'trend_v1',
#
# 0.47128 - v117_1
# 'ewm_lags12_v2',
#  'grp'
#
# 0.47476 - v118
# #'ewm_lags12_v2',
#  'ewm_lags29_v3',
#  'num_lags44_v4',
#  'num_lags46_v4',
#  'num_lags51_v4'
#
# 0.47610 - v119
# #'ewm_lags12_v2',
#  'ewm_lags29_v3',
#  'num_lags51_v4'
#
#
# 0.4729 - v120
# #'ewm_lags12_v2',
# 'ewm_lags29_v3'
#
# 0.47526 - v121
# #'ewm_lags12_v2',
#  'num_lags44_v4',
#  'num_lags51_v4'
#
# 2.2764 - v122
# 'pred_f'
#
# 0.49104 - v123
# 'pred_1583'
#
# 2.05943 - v124
# 'prob_pred'
#
# -------------------interval pred ends 1750-------------
#
# 0.47009 - v126---add 2 store
# 'pred_div_ca_wi'
#
# 0.47104 - v127
# 'pred_diff_ca_wi'
#
# **0.46665 - v128**
# 'pred_mean_ca_wi'
#
# 0.46771 - v129 ---add 3 store
# 'pred_div_ca_wi_tx'
#
# 0.46859 - v130 'pred_diff_ca_wi_tx'
#
# 0.46809 - v131 'pred_mean_ca_wi_tx'
#
# 0.46844 - v132 'pred_diff_multt_ca_wi_tx'
#
# 0.47348 - v133 'pred_std'
#
# 0.47185 - v134  'pred_div_ca_wi_tx', 'pred_std'
#
# -----------------------interval change 2000
#
# 0.47388 - v135 all no drop, mean pred
#
# 0.46915 - v136 drop in pred last 28*3 days(nana), mean pred
#
# 0.47029 - v137 drop in pred last 28*5 days(nana), mean pred
#
# 0.4696 - v138 two ca wi,  28*3 days(nana)
#
# 0.4666 - v139 load only two ca-wi ends period 1750
#
# -----------------**10 day to ends**---------------
# v1 all make 1750 and pred
#
# v1_1 only 2store
#
# ---train
#
# ca1_2 train 2000 interval
#
#
#
# Trained:
#
# full CA4, full CA3
# and split ca4_1,2, ca3_1,2 если полные будут с ошибкой
#
#
# Maked:
#
# ca1_2, version 2
# ca2 Fork of predict_clf_make_v2_ca_2, named 3 but pred 2
#
# wi1_2, version 2
# wi2 trained 1750, predict_clf_make_v2_wi_2
# wi3 Fork of predict_clf_make_v2_wi_2
#
# tx1_2, version 2
# tx2 predict_clf_make_v2_tx_2
# tx3 Fork of predict_clf_make_v2_tx_2
#
# **0.46634 - v140 add for best score ewm**
#
# all maked
#
# 0.47028 - v141 ca1-4, wi1-3 mean
#
# 0.46985 - v142 all mean, 'ewm_lags12_v2',
#
# 0.46742 - v143 ca1-4, wi1-3 diff, 'ewm_lags12_v2'
#
# 0.46941 - v144 all diff
#
# 0.46863 - v145 all + std,  'ewm_lags12_v2',
#
# 0.47115 - v146 ca1-4, wi1-3 mean + std for allб 'ewm_lags12_v2',
#
# 0.47156 - v147 mean ca1, ca3, pred wi2
#
# 0.47430 - v148 for each store std, mean by train if  ca mean ca
#
# 0.47386 - v149 std each store ca, wi, tx, 'ewm_lags12_v2',
#
# 0.47132 - v150 mean by train if  ca mean ca, 'ewm_lags12_v2',
#
# ---8 day to ends
# надо определиться
#
# 0.46634 - v140 add for best score ewm, train1, version 29
#
# 0.46742 - v143 ca1-4, wi1-3 diff, train3, version 17
#
# 0.47105 - v151 peretest v145 all + std
#
# 0.4678 - v152 v142 all mean dell ewm
#
# 0.4687 - v153 v143 ca1-4, wi1-3 diff, dell evm
#
# 0.4742 - v154 ca1-4, wi1-3 diff + std by ca&wi
#
# 0.4715 - v155 ca1-4, wi1-3 diff + std all
#
# 0.47102 - v156 v142 + std by ca&wi
#
# 0.4685 - v158 v140 learning rate 0.02
#
# 0.4711 - v157
#
# 0.4685 - v159 v140 bin 50
#
# 0.4675 - v160 v140 num_l&min_data +1
#
# ------------------tune param
#
# 0.46685 - v161 add extra tree
#
# 0.52306 - v162 lgb_params = {
#     'tweedie_variance_power': 1.1,
#     'subsample': 0.9,
#     'learning_rate':0.03,
#     'num_leaves': 1000,
#     'min_data_in_leaf': 1000,
#     'feature_fraction': 0.8,
#     'max_bin': 100,
#     }
#
# 0.57638 - v163lgb_params = {
#     'tweedie_variance_power': 1.3,
#     'subsample': 0.9,
#     'learning_rate':0.03,
#     'num_leaves': 1000,
#     'min_data_in_leaf': 1000,
#     'feature_fraction': 0.8,
#     'max_bin': 100,
#     }
#
# 0.47579 - v164 lgb_params = {
#     'tweedie_variance_power': 1.1,
#     'subsample': 0.9,
#     'learning_rate':0.03,
#     'num_leaves': 2**11-1,
#     'min_data_in_leaf': 2**12-1,
#     'feature_fraction': 0.8,
#     'max_bin': 100,
#     }
#
# 0.53028 - v165 lgb_params = {
#     'tweedie_variance_power': 1.2,
#     'subsample': 0.9,
#     'learning_rate':0.03,
#     'num_leaves': 495,
#     'min_data_in_leaf': 247,
#     'feature_fraction': 0.8,
#     'max_bin': 100,
#     }
#
# 0.57527 - v166 {'bagging_fraction': 1.0,
#  'feature_fraction': 0.9,
#  'min_data_in_leaf': 2047,
#  'num_leaves': 4095,
#  'tweedie_variance_power': 1.2000000000000002}
#
# 0.50251 - v167
# {'bagging_fraction': 1.0,
#  'feature_fraction': 0.9,
#  'min_data_in_leaf': 4095,
#  'num_leaves': 2047,
#  'tweedie_variance_power': 1.2000000000000002
#
# 0.49881 - v168 for ca
# {'bagging_fraction': 1.0,
#  'feature_fraction': 0.9,
#  'min_data_in_leaf': 2047,
#  'num_leaves': 4095,
#  'tweedie_variance_power': 1.2000000000000002}
#
# 0.46506 - v169 max depth 40
#
# 0.4752 - v170 max ddepth 11
#
# find depth
#
# 0.46654 - v171 37, 1.2
#
# 0.57 - v172 'min_data_in_leaf': 2**10-1, for all
#
# 0.47 - v173 'min_data_in_leaf': 2**10-1, ca1, ca3, wi2

# %% [markdown]
# max_bin сильно не заметил надо после всего потестить
# (меньше лучше вроде)
#
# увеличение баггинг уменьшает ошибку
#
# 0.46729 - v174 bagging_fraction: 0.7 all
#
# 0.46729 - v175 b_f 0.7 ca-wi
#
# 0.49004 - v177
#
#     lgb_params = {
#         'tweedie_variance_power': 1.1,
#         'bagging_fraction': 0.7,
#         'min_data_in_leaf': 2**10-1,
#         'max_bin': 50,
#         'max_depth': 38
#         }
#
# я буду тренить са1,3 и ви2
# буду смотреть на ошибку падает тестим предикт
#
# cv wrmsse tune param
#
# 0.46492 - v178 169 extra_trees --(v2, version21)
#
# 0.46506 - v179 169 extra_trees, max bin 50
#
# 0.47923 - v180 169, path_smooth,  'learning_rate':0.009
#
# 0.61508 - v181 dart
#
# 0.4935 - v182 bagging 0.8, min_leaf 2047
#
#
#
# v183 dart n_estimators 2000
#
# 0.47086 - v184 min_leaf 2047
#    'max_depth': 40,
#    'extra_trees': True
#    max_bin 50
#
# 0.47220 - v185 bagging 0.8
# 'extra_trees': True
#
#
# 0.4687 - v186 best score  v178 n_estimator 1600
#
# 0.4779 - v187 min_leaf 2047, max_bin 100
#
#
# 0.46849 v188 max depth 38, extra_tree
#
# 0.46853 v189 max depth 42, extra_tree
#
# 0.46669 - 190 min estimator = 1200,
# 'extra_trees': True,
# 'max_depth': 40
#
# 0.51880 - 191
#     'learning_rate':0.005,
#     'n_estimators': 1000,
#     'extra_trees': True,
#
# 0.48719 - 192
#     'learning_rate':0.005,
#     'n_estimators': 1000,
#     'extra_trees': True,
#     'n_estimators': 1600,
#
# 0.47929 - v193 n_estimator 2200
#
# 0.50779 - v194(93) add roll lags ewm
#
# v195(94) add roll deffault
#
# 0.46506 - v196 best train for ones
#
# 0.46685 - v197 drop extra&depth
#
# 0.46492 - v198 169 extra_trees --(v2, version21)
#
# 0.46827 v200 model 2, 'extra_trees': True, 'max_depth': 40
#
# 0.46950 v201 add roll lags deffa drop
# 'extra_trees': True,
# 'max_depth': 40
#
# 0.46715 v202 ewm drop
# 'extra_trees': True,
# 'max_depth': 40
#
# 0.46743 - v204 model 2, drop
#
# 0.46953 - v205 model2 edd new lags ewm < 20
#
# 0.46953 - v206 model2 edd new lags ewm add 20
#
# 0.46904 - v207 model 1 add all new ewm lag
#
# 0.66010 - v208 v204 train by ones seed 13
#
#
#
# ----add eval data
# Fork_v3_with_eval
#
# 0.87844 - v199 add default eval data
#
# 0.78839 - v203 drop all  pred ew
